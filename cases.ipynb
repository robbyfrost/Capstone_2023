# %%
import xarray as xr
import numpy as np

# %%
ds = xr.open_dataset("/Users/robertfrost/Documents/boomsoon/2023_semester_2/capstone/analysis/capstone_2023.nc")

# %%
ds.where(ds.flash_number == 0, drop=True)
# Out:
# <xarray.Dataset>
# Dimensions:                         (mesocyclone_track_points: 1603,
#                                      number_of_flashes: 500)
# Coordinates:
#   * mesocyclone_track_points        (mesocyclone_track_points) int64 348 ... ...
#   * number_of_flashes               (number_of_flashes) int64 0 1 2 ... 498 499
# Data variables: (12/18)
#     mesocyclone_id                  (mesocyclone_track_points) object 201306-...
#     mesocyclone_year                (mesocyclone_track_points) float64 2.013e...
#     mesocyclone_month               (mesocyclone_track_points) float64 6.0 .....
#     mesocyclone_day                 (mesocyclone_track_points) float64 6.0 .....
#     mesocyclone_hour                (mesocyclone_track_points) float64 5.0 .....
#     mesocyclone_minute              (mesocyclone_track_points) float64 50.0 ....
#     ...                              ...
#     flash_latitude                  (mesocyclone_track_points, number_of_flashes) float32 ...
#     flash_longitude                 (mesocyclone_track_points, number_of_flashes) float32 ...
#     flash_height                    (mesocyclone_track_points, number_of_flashes) float32 ...
#     flash_time                      (mesocyclone_track_points, number_of_flashes) timedelta64[ns] ...
#     flash_amplitude                 (mesocyclone_track_points, number_of_flashes) float32 ...
#     tc_name                         (mesocyclone_track_points) object Andrea-...

# %%
tc = ds.where(ds.tc_name == "Andrea-13", drop=True)

# %%
tce = tc.where(tc.flash_number > 0, drop=True)
tcn = tc.where(tc.flash_number == 0, drop=True)

# %%
tcn.mesocyclone_id
# Out:
# <xarray.DataArray 'mesocyclone_id' (mesocyclone_track_points: 105)>
# array(['201306-017', '201306-017', '201306-017', '201306-017',
#        '201306-017', '201306-017', '201306-017', '201306-017',
#        '201306-017', '201306-017', '201306-017', '201306-017',
#        '201306-017', '201306-017', '201306-017', '201306-017',
#        '201306-017', '201306-018', '201306-018', '201306-018',
#        '201306-018', '201306-018', '201306-018', '201306-018',
#        '201306-018', '201306-018', '201306-018', '201306-018',
#        '201306-018', '201306-020', '201306-020', '201306-020',
#        '201306-020', '201306-020', '201306-020', '201306-020',
#        '201306-020', '201306-021', '201306-021', '201306-021',
#        '201306-021', '201306-021', '201306-021', '201306-022',
#        '201306-022', '201306-022', '201306-022', '201306-022',
#        '201306-022', '201306-022', '201306-022', '201306-022',
#        '201306-022', '201306-022', '201306-022', '201306-022',
#        '201306-023', '201306-023', '201306-023', '201306-023',
#        '201306-023', '201306-023', '201306-023', '201306-023',
#        '201306-023', '201306-023', '201306-023', '201306-023',
#        '201306-024', '201306-024', '201306-024', '201306-024',
#        '201306-024', '201306-024', '201306-025', '201306-025',
#        '201306-025', '201306-025', '201306-025', '201306-025',
#        '201306-025', '201306-025', '201306-025', '201306-025',
#        '201306-026', '201306-026', '201306-026', '201306-026',
#        '201306-026', '201306-026', '201306-026', '201306-026',
#        '201306-026', '201306-026', '201306-027', '201306-027',
#        '201306-027', '201306-027', '201306-027', '201306-027',
#        '201306-027', '201306-027', '201306-027', '201306-027',
#        '201306-027'], dtype=object)
# Coordinates:
#   * mesocyclone_track_points  (mesocyclone_track_points) int64 348 349 ... 466
# Attributes:
#     units:      formatted as YYYYMM-NUM
#     long_name:  Unique ID of mesocyclone
#     notes:       subjectively tracked by Sandmael

# %%
meso = ds.where(ds.mesocyclone_id == "201306-020", drop=True)
print(f"{meso.mesocyclone_latitude[0].values}, {meso.mesocyclone_longitude[0].values - 360}")
meso.flash_number
# print(f"{int(meso.mesocyclone_year[0].values)}-{int(meso.mesocyclone_month[0].values)}-{int(meso.mesocyclone_day[0].values)} {int(meso.mesocyclone_hour[0].values)}:{int(meso.mesocyclone_minute[0].values)}")
# print(f"{int(meso.mesocyclone_year[11].values)}-{int(meso.mesocyclone_month[11].values)}-{int(meso.mesocyclone_day[11].values)} {int(meso.mesocyclone_hour[11].values)}:{int(meso.mesocyclone_minute[11].values)}")
# meso.mesocyclone_day
# Out:
# 26.4091, -80.20569999999998
# <xarray.DataArray 'flash_number' (mesocyclone_track_points: 12)>
# array([0., 0., 0., 0., 0., 0., 2., 2., 4., 0., 0., 1.], dtype=float32)
# Coordinates:
#   * mesocyclone_track_points  (mesocyclone_track_points) int64 377 378 ... 388
# Attributes:
#     long_name:  Number of flashes within 10-km radius within 10-minutes of me...
#     notes:      From Earth Networks
